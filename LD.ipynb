# %%
# !pip install flask_ngrok
# !pip install langdetect

# %%
# %%writefile predict.html
#
# <!doctype html>
# <html lang="en">
#     <script>
#     function show_test()
# 	  {
# 	    document.getElementById("actualshow").removeAttribute("hidden");
# 	  }
#     </script>
#   <style>
#     #button{
#         text-align: center;
#         display: inline-block;
#         position: absolute;
#         top: 50%;
#         left: 50%;
#     }
#   </style>
#   <head class="p-3 mb-2 bg-dark text-white">
#     <!-- Required meta tags -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <!-- Bootstrap CSS -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" crossorigin="anonymous">
#
#     <title>LANGUAGE_PREDICTION</title>
#     <nav class="navbar navbar-dark bg-dark">
#         <div class="container-fluid">
#         <a class="navbar-brand" href="#">LANGUAGE_PREDICTION</a>
#         <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">
#           <span class="navbar-toggler-icon"></span>
#         </button>
#         <div class="collapse navbar-collapse" id="navbarSupportedContent">
#           <ul class="navbar-nav me-auto mb-2 mb-lg-0">
#             <li class="nav-item">
#               <a class="nav-link active" aria-current="page" href="/">Home</a>
#             </li>
#             <li class="nav-item dropdown">
#               <a class="nav-link dropdown-toggle" href="#" id="navbarDropdown" role="button" data-bs-toggle="dropdown" aria-expanded="false">
#                 OUR MODEL
#               </a>
#               <ul class="dropdown-menu" aria-labelledby="navbarDropdown">
#                 <li><a class="dropdown-item" href="/actual">ACTUAL LANGUAGE</a></li>
#                 <li><a class="dropdown-item" href="/test_predict">PREDICTED LANGUAGE</a></li>
#                 <li><a class="dropdown-item" href="/accuracy">Know Our Model</a></li>
#                 <li><hr class="dropdown-divider"></li>
#                 <li><a class="dropdown-item" href="/aboutus">ABOUT US</a></li>
#
#               </ul>
#             </li>
#           </ul>
#         </div>
#       </div>
#     </nav>
#   </head>
#   <body>
#
#     <center>
#           <div id="carouselExampleCaptions" class="carousel slide" data-bs-ride="carousel">
#       <div class="carousel-indicators">
#         <button type="button" data-bs-target="#carouselExampleCaptions" data-bs-slide-to="0" class="active" aria-current="true" aria-label="Slide 1"></button>
#         <button type="button" data-bs-target="#carouselExampleCaptions" data-bs-slide-to="1" aria-label="Slide 2"></button>
#         <button type="button" data-bs-target="#carouselExampleCaptions" data-bs-slide-to="2" aria-label="Slide 3"></button>
#       </div>
#       <div class="carousel-inner">
#         <div class="carousel-item active">
#           <img src="https://www.macmillandictionaryblog.com/wp-content/uploads/2013/02/International-Mother-Language-Day-1-768x315.jpg" class="d-block w-100" alt="...">
#           <div class="carousel-caption d-none d-md-block">
#
#           </div>
#         </div>
#         <div class="carousel-item">
#           <img src="https://scontent.fblr4-3.fna.fbcdn.net/v/t31.18172-8/17436181_106004946584225_2944305367365430965_o.png?_nc_cat=110&ccb=1-3&_nc_sid=e3f864&_nc_ohc=CXpiDNQYoLEAX86LhOK&_nc_ht=scontent.fblr4-3.fna&oh=6c3ce05dee37cc31dcbfd7fc4a82b4e5&oe=60E56CF9" class="d-block w-100" alt="...">
#           <div class="carousel-caption d-none d-md-block">
#
#           </div>
#         </div>
#         <div class="carousel-item">
#           <img src="https://mir-s3-cdn-cf.behance.net/project_modules/disp/a48cb513891679.56279d7fcbe6e.png" class="d-block w-100" alt="...">
#           <div class="carousel-caption d-none d-md-block">
#
#           </div>
#         </div>
#       </div>
#       <button class="carousel-control-prev" type="button" data-bs-target="#carouselExampleCaptions" data-bs-slide="prev">
#         <span class="carousel-control-prev-icon" aria-hidden="true"></span>
#         <span class="visually-hidden">Previous</span>
#       </button>
#       <button class="carousel-control-next" type="button" data-bs-target="#carouselExampleCaptions" data-bs-slide="next">
#         <span class="carousel-control-next-icon" aria-hidden="true"></span>
#         <span class="visually-hidden">Next</span>
#       </button>
#     </div>
#
#     <!--img src="http://www.padhaaro.com/blog/wp-content/uploads/2015/09/9429334.png" class="img-fluid" alt="image"-->
#     <br>
#     <button onclick="show_test()" class="btn btn-danger">TRY OUT OUR MODEL </button>
#     <div hidden id="actualshow">
#     <form action="{{url_for('urown')}}" method="post">
#       <div class="mb-3">
#       <label for="exampleInputEmail1" class="form-label" >Enter Text</label>
#       <input type="text" class="form-control" id="exampleInputEmail1" aria-describedby="emailHelp" placeholder="ENTER TEXT" name="urtext" >
#       <div id="emailHelp" class="form-text">Entered LANGUAGE will be predicted</div>
#       </div>
#     <button type="submit" class="btn btn-primary">submit</button>
#     </form>
#     <h6> Predicted LANGUAGE </h6>
#     </div>
#     <br>
#     {{ prediction_text3}}
#     <br>
#     <br>
#     <p>
#       Languages spoken in India belong to several language families, the major ones being the Indo-Aryan languages spoken by 78.05% of Indians and the Dravidian languages spoken by 19.64% of Indians.[6][7] Languages spoken by the remaining 2.31% of the population belong to the Austroasiatic, Sino–Tibetan, Tai–Kadai and a few other minor language families and isolates.[8]:283 India has the world's fourth highest number of languages (447), after Nigeria (524), Indonesia (710) and Papua New Guinea (840).[9]
#     </p><p>
#       Article 343 of the Indian constitution stated that the official language of the Union is Hindi in Devanagari script instead of the extant English. Later, a constitutional amendment, The Official Languages Act, 1963, allowed for the continuation of English alongside Hindi in the Indian government indefinitely until legislation decides to change it.[2] The form of numerals to be used for the official purposes of the Union are "the international form of Indian numerals",[10][11] which are referred to as Arabic numerals in most English-speaking countries.[1] Despite the misconceptions, Hindi is not the national language of India; the Constitution of India does not give any language the status of national language.[12][13]
#     </p>
#     <!-- Optional JavaScript; choose one of the two! -->
#
#     <!-- Option 1: Bootstrap Bundle with Popper -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script>
#
#     <!-- Option 2: Separate Popper and Bootstrap JS -->
#     <!--
#     <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.9.2/dist/umd/popper.min.js" integrity="sha384-IQsoLXl5PILFhosVNubq5LC7Qb9DXgDA9i+tQ8Zj3iwWAwPtgFTxbJ8NT4GN1R8p" crossorigin="anonymous"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.min.js" integrity="sha384-cVKIPhGWiC2Al4u+LWgxfKTRIcfu0JTxR+EQDz/bgldoEyl4H0zUF0QKbrJ0EcQF" crossorigin="anonymous"></script>
#     -->
#     </center>
#   </body>
#
# </html>
# Out:
# Writing predict.html

# %%
# %%writefile actual.html
#
#
# <!doctype html>
# <html lang="en">
#   <script>
#     function show_actual()
# 	  {
# 	    document.getElementById("actualshow").removeAttribute("hidden");
# 	  }
#   </script>
#   <center>
#   <head class="p-3 mb-2 bg-dark text-white">
#     <!-- Required meta tags -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <!-- Bootstrap CSS -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" crossorigin="anonymous">
#
#     <title>LANGUAGE_PREDICTION</title>
#   </head>
#   <body>
#
#     <img src="https://thumbs.dreamstime.com/b/multiracial-group-people-greeting-different-languages-various-nationalities-saying-hello-cartoon-characters-chinese-indian-194898452.jpg" class="img-fluid" alt="image">
#
#     <h1>LANGUAGE_PREDICTION</h1>
#     <!--form action="{{url_for('actual')}}" method="POST"-->
#
#     <button onclick="show_actual()" class="btn btn-warning">ACTUAL LANGUAGE</button>
#     <div hidden id="actualshow">
#     {% for item in prediction_text %}
#     <table class="table"">
#       <thead>
#       <tr scope="col"></tr>
#     </thead>
#     <tbody>
#       <tr class="table-primary">
#         <td class="table-primary">{{item}}</td>
#       </tr>
#     </tbody>
#     {%endfor%}
#     </table>
#     </div>
#     <br>
#
#     <!-- Optional JavaScript; choose one of the two! -->
#
#     <!-- Option 1: Bootstrap Bundle with Popper -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script>
#
#     <!-- Option 2: Separate Popper and Bootstrap JS -->
#     <!--
#     <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.9.2/dist/umd/popper.min.js" integrity="sha384-IQsoLXl5PILFhosVNubq5LC7Qb9DXgDA9i+tQ8Zj3iwWAwPtgFTxbJ8NT4GN1R8p" crossorigin="anonymous"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.min.js" integrity="sha384-cVKIPhGWiC2Al4u+LWgxfKTRIcfu0JTxR+EQDz/bgldoEyl4H0zUF0QKbrJ0EcQF" crossorigin="anonymous"></script>
#     -->
#   </body>
#   </center>
# </html>
# Out:
# Writing actual.html

# %%
# %%writefile test.html
#
#
# <!doctype html>
# <html lang="en">
#   <script>
#     function show_test()
# 	  {
# 	    document.getElementById("actualshow").removeAttribute("hidden");
# 	  }
#   </script>
#   <center>
#   <head class="p-3 mb-2 bg-dark text-white">
#     <!-- Required meta tags -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <!-- Bootstrap CSS -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" crossorigin="anonymous">
#
#     <title>LANGUAGE_PREDICTION</title>
#   </head>
#   <body>
#
#     <img src="https://gumlet.assettype.com/swarajya/2020-08/0de583ae-3cff-4770-a7c5-98369ecc69a1/Untitled.png?w=1200&h=800" class="img-fluid" alt="image">
#
#     <h1>LANGUAGE_PREDICTION</h1>
#       <!--form action="{{url_for('test_predict')}}" method="GET"-->
#       <button onclick="show_test()" class="btn btn-danger">PREDICTED LANGUAGE</button>
#       <br>
#       <div hidden id="actualshow">
#       {% for item in prediction_text1 %}
#       <table class="table"">
#         <thead>
#         <tr scope="col"></tr>
#       </thead>
#       <tbody>
#         <tr class="table-primary">
#           <td class="table-primary">{{item}}</td>
#         </tr>
#       </tbody>
#       {%endfor%}
#       </table>
#       <br>
#       </div>
#
#     <!-- Optional JavaScript; choose one of the two! -->
#
#     <!-- Option 1: Bootstrap Bundle with Popper -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script>
#
#     <!-- Option 2: Separate Popper and Bootstrap JS -->
#     <!--
#     <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.9.2/dist/umd/popper.min.js" integrity="sha384-IQsoLXl5PILFhosVNubq5LC7Qb9DXgDA9i+tQ8Zj3iwWAwPtgFTxbJ8NT4GN1R8p" crossorigin="anonymous"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.min.js" integrity="sha384-cVKIPhGWiC2Al4u+LWgxfKTRIcfu0JTxR+EQDz/bgldoEyl4H0zUF0QKbrJ0EcQF" crossorigin="anonymous"></script>
#     -->
#   </body>
#   </center>
# </html>
# Out:
# Writing test.html

# %%
# %%writefile accuracy.html
#
#
#
#
# <!doctype html>
# <html lang="en">
#   <style>
#     #button{
#         text-align: center;
#         display: inline-block;
#         position: absolute;
#         top: 50%;
#         left: 50%;
#     }
#   </style>
#   <center>
#   <head class="p-3 mb-2 bg-dark text-white">
#     <!-- Required meta tags -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <!-- Bootstrap CSS -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" crossorigin="anonymous">
#
#     <title>LANGUAGE_PREDICTION</title>
#   </head>
#   <body>
#
#     <img src="https://www.thoughtco.com/thmb/KHcKJtIVy2JlmNYS5_rOZ8jMXQU=/3868x2176/smart/filters:no_upscale()/Getty_language-550382899-56afa52a5f9b58b7d01b7333.jpg" class="img-fluid" alt="image">
#
#     <h1>LANGUAGE_PREDICTION</h1>
#     <p>We trained the model for these Langages</p>
#     <ul class="list-group">
#       <li class="list-group-item active" aria-current="true">LANGUAGES</li>
#       <li class="list-group-item">Tamil</li>
#       <li class="list-group-item">Telgu</li>
#       <li class="list-group-item">Kannada</li>
#     </ul>
#     <h6>We got {{prediction_text2}}</h6>
#     <br>
#     <img src="{{url_for('static',filename='pic.png')}}"  alt="image">
#
#
#     <!-- Optional JavaScript; choose one of the two! -->
#
#     <!-- Option 1: Bootstrap Bundle with Popper -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script>
#
#     <!-- Option 2: Separate Popper and Bootstrap JS -->
#     <!--
#     <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.9.2/dist/umd/popper.min.js" integrity="sha384-IQsoLXl5PILFhosVNubq5LC7Qb9DXgDA9i+tQ8Zj3iwWAwPtgFTxbJ8NT4GN1R8p" crossorigin="anonymous"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.min.js" integrity="sha384-cVKIPhGWiC2Al4u+LWgxfKTRIcfu0JTxR+EQDz/bgldoEyl4H0zUF0QKbrJ0EcQF" crossorigin="anonymous"></script>
#     -->
#   </body>
#   </center>
# </html>
# Out:
# Writing accuracy.html

# %%
# %%writefile about.html
#
#
# <!doctype html>
# <html lang="en">
#   <head class="p-3 mb-2 bg-dark text-white">
#     <!-- Required meta tags -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <!-- Bootstrap CSS -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" crossorigin="anonymous">
#
#     <title>LANGUAGE_PREDICTION</title>
#   </head>
#   <body>
#       <ul class="list-unstyled">
#
#       <li><strong>Project on:</strong> </li>
#       <div class="p-3 mb-2 bg-primary text-white">
#       <li><strong>Language Classification using Machine Learning</strong></li>
#       </div>
#       <br>
#       <br>
#       <li><strong>Presented By</strong>:
#       <br>
#       <div class="p-3 mb-2 bg-warning text-dark">
#         <ul>
#           <ul class="list-inline">
#             <li class="list-inline-item">Trupti Kulkarni</li>
#             <li class="list-inline-item">-2BA18IS080</li>
#           </ul>
#           <ul class="list-inline">
#             <li class="list-inline-item">Anupama Vandal</li>
#             <li class="list-inline-item">-2BA18IS012</li>
#           </ul>
#           <ul class="list-inline">
#             <li class="list-inline-item">Sushmita Patil</li>
#             <li class="list-inline-item">-2BA18IS077</li>
#           </ul>
#           <ul class="list-inline">
#             <li class="list-inline-item">Vaidurya Bonageri</li>
#             <li class="list-inline-item">-2BA18IS083</li>
#           </ul>
#         </ul>
#       </div>
#       </li>
#       <br>
#       <br>
#       <li><strong>  Guided By - </strong> </li>
#       <div class="p-3 mb-2 bg-info text-white">
#       <li>Dr.B.M Reshmi</li>
#       </div>
#     </ul>
#
#
#
#     <!-- Optional JavaScript; choose one of the two! -->
#
#     <!-- Option 1: Bootstrap Bundle with Popper -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script>
#
#     <!-- Option 2: Separate Popper and Bootstrap JS -->
#     <!--
#     <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.9.2/dist/umd/popper.min.js" integrity="sha384-IQsoLXl5PILFhosVNubq5LC7Qb9DXgDA9i+tQ8Zj3iwWAwPtgFTxbJ8NT4GN1R8p" crossorigin="anonymous"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.min.js" integrity="sha384-cVKIPhGWiC2Al4u+LWgxfKTRIcfu0JTxR+EQDz/bgldoEyl4H0zUF0QKbrJ0EcQF" crossorigin="anonymous"></script>
#     -->
#
#   </body>
#
# </html>
# Out:
# Writing about.html

# %%
# !mkdir templates

# %%
# !mv /content/actual.html /content/templates
# !mv /content/predict.html /content/templates
# !mv /content/test.html /content/templates
# !mv /content/accuracy.html /content/templates
# !mv /content/about.html /content/templates

# %%
# !mkdir static

# %%
#Back end code
import numpy as np
import collections
import pandas as pd
import flask
from flask import Flask, render_template, request
import pickle
import numpy as np
from flask_ngrok import run_with_ngrok
import warnings
from csv import writer
from langdetect import detect
warnings.filterwarnings('ignore')

app = Flask(__name__)
run_with_ngrok(app)

df=pd.read_csv("/content/final_merged_2.csv")
df = df.dropna() # remove null values for the "text" column
df['text'] = df['text'].astype(str) # Convert the column "text" from object to a string in order to operate on it
df['language'] = df['language'].astype(str)
punc = ('!', "," ,"\'" ,";" ,"\"", ".", "-" ,"?")
vowels=['a','e','i','o','u']
df['word_count'] = df['text'].apply(lambda x : len(x.split()))
df['character_count'] = df['text'].apply(lambda x : len(x.replace(" ","")))
df['num_vowels'] = df['text'].apply(lambda x : sum([any(v in a for v in vowels) for a in x.split()]))
df['vowel_density'] = df['num_vowels']/df['word_count']
df['word_density'] = df['word_count'] / (df['character_count'] + 1)
df['punc_count'] = df['text'].apply(lambda x : len([a for a in x if a in punc]))
df['num_exclamation_marks'] =df['text'].apply(lambda x: x.count('!'))
df['num_question_marks'] = df['text'].apply(lambda x: x.count('?'))
df['num_punctuation'] = df['text'].apply(lambda x: sum(x.count(w) for w in punc))
df['num_unique_words'] = df['text'].apply(lambda x: len(set(w for w in x.split())))
df['num_repeated_words'] = df['text'].apply(lambda x: len([w for w in collections.Counter(x.split()).values() if w > 1]))
df['words_vs_unique'] = df['num_unique_words'] / df['word_count']
a=df.corr(method='pearson')
a
b=df.groupby('language').mean().T
b
import seaborn as sns
sns.set(style="ticks")
sns.pairplot(df)
from sklearn.model_selection import train_test_split #split dataset into features and target variable
feature_cols = list(df.columns)[2:]
X = df[feature_cols] # Features
y = df[['language']] # Target variable
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # 80% train and 20% test
X_train, X_test, y_train, y_test


info = pd.DataFrame(X_test) 
index2=info.index
index1=df.index
column_B = df.iloc[index2, 0]
test_list = column_B.tolist() 

info = pd.DataFrame(y_test) 
index2=info.index
index1=df.index
column_B = df.iloc[index2, 1]
test_list1 = column_B.tolist() 



from sklearn.decomposition import PCA # Principal component analysis used to reduce the number of features in a model
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(X_train)
# Transform both the training set and the test set.
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Make an instance of the model to retain 95% of the variance within the old features.
pca = PCA(.95)
pca.fit(X_train)
print('Number of Principal Components = '+str(pca.n_components_))
# Number of Principal Components = 13

X_train = pca.transform(X_train)
X_test = pca.transform(X_test)
from sklearn.tree import DecisionTreeClassifier
import pickle
dt_clf = DecisionTreeClassifier() # Create Decision Tree classifer object
dt_clf = dt_clf.fit(X_train,y_train) # Fit/Train Decision Tree Classifer on training set

# Save model to file in the current working directory so that it can be imported and used.
# I use the pickle library to save the parameters of the trained model
pkl_file = "decision_tree_model.pkl"
with open(pkl_file, 'wb') as file:
    pickle.dump(dt_clf, file)

# Load previously trained model from pickle file
with open(pkl_file, 'rb') as file:
    dt_clf = pickle.load(file)

dt_clf # parameters of the Decision Tree model are shown below and can be further optimized to improve model performance

y_pred = dt_clf.predict(X_test) #Predict the response for test dataset

temp=[]
for i,j in zip(y_pred,test_list):
  string6=j+"           --->          "+i;
  temp.append(string6)

temp1=[]
for i,j,k in zip(y_pred,test_list,test_list1):
  string5=j+"           --->          "+k;
  temp1.append(string5)
#print(temp)


from sklearn.metrics import accuracy_score
accuracy_score_dt = accuracy_score(y_test, y_pred)
print(accuracy_score_dt)
import matplotlib.pyplot as plt
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
labels = ['Tamil','Telgu','Kannada']
# Confusion Matrix
cm_Model_dt = confusion_matrix(y_test, y_pred, labels)
fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(111)
sns.heatmap(cm_Model_dt, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r')
plt.ylabel('Actual')
plt.xlabel('Predicted')
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
title = 'Decision Tree Model Accuracy Score = '+ str(round(accuracy_score_dt*100,2)) +"%"
plt.title(title, size = 15)
plt.savefig('/content/pic.png')
# Out:
# Number of Principal Components = 7
# 0.843167701863354

# %%
# !mv /content/pic.png /content/static

# %%
app = Flask(__name__)
run_with_ngrok(app)

@app.route('/', methods=['GET'])
def home():
  return render_template('predict.html')

@app.route('/actual', methods=[ "GET", "POST"])
def actual():
  return render_template('actual.html', prediction_text= temp1)

@app.route('/test_predict', methods=[ "GET", "POST"])
def test_predict():
    return render_template('test.html',prediction_text1= temp)
  
@app.route('/accuracy', methods=[ "GET", "POST"])
def accuracy():
    return render_template('accuracy.html',prediction_text2= title)

@app.route('/aboutus', methods=[ "GET", "POST"])
def aboutus():
    return render_template('about.html')

@app.route('/urown', methods=[ "GET", "POST"])
def urown():
    input_values = [str(x) for x in request.form.values()]
    string10=detect(input_values[0])
    if string10=='kn':
      return render_template('predict.html',prediction_text3="Kannada")
    if string10=='te':
      return render_template('predict.html',prediction_text3= "Telgu")
    if string10=='ta':
      return render_template('predict.html',prediction_text3= "Tamil")
    else:
       return render_template('predict.html',prediction_text3= "NO TRAINED FOR THIS LANGUAGE")

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://47333eda9acc.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [09/Jul/2021 04:10:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 04:10:06] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2021 04:10:16] "POST /urown HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 04:10:22] "GET /actual HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 04:10:44] "GET /test_predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 04:11:01] "GET /accuracy HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 04:11:01] "GET /static/pic.png HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 04:50:15] "POST /urown HTTP/1.1" 200 -
# ...
